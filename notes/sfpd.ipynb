# %% [markdown]
# # Crime data visualization in San Francisco
#
# San Francisco has one of the most "open data" policies of any large city. In this lab, we are going to download about 85M of data (238,456) describing all police incidents since 2018 (I'm grabbing data on August 5, 2019).
#
# ## Getting started
#
# Download [Police Department Incident Reports 2018 to present](https://data.sfgov.org/Public-Safety/Police-Department-Incident-Reports-2018-to-Present/wg3w-h783) or, if you want, all [San Francisco police department incident since 1 January 2003](https://data.sfgov.org/Public-Safety/SFPD-Incidents-from-1-January-2003/tmnf-yvry). Click the "Export" button and then save in "CSV for Excel" format. (It's fairly large at all 140MB so it could take a while if you have a slow connection.)
#
# We can easily figure out how many records there are:
#
# ```bash
# $ wc -l Police_Department_Incident_Reports__2018_to_Present.csv
#   388670 Police_Department_Incident_Reports__2018_to_Present.csv
# ```
#
# So 388,669 not including the header row.  You can name that data file whatever you want but I will call it `SFPD.csv` for these exercises and save it in `/tmp`.

# %% [markdown]
# ## Sniffing the data
#
# Let's assume the file you downloaded and is in `/tmp`:

# %%
import pandas as pd

df_sfpd = pd.read_csv('/tmp/SFPD.csv')
df_sfpd.head(10).T
# Out:
#                                                                            0  \
# Incident Datetime                                     2020/08/15 08:56:00 AM
# Incident Date                                                     2020/08/15
# Incident Time                                                          08:56
# Incident Year                                                           2020
# Incident Day of Week                                                Saturday
# Report Datetime                                       2020/08/15 08:56:00 AM
# Row ID                                                           95300907041
# Incident ID                                                           953009
# Incident Number                                                    200474239
# CAD Number                                                               NaN
# Report Type Code                                                          VS
# Report Type Description                                   Vehicle Supplement
# Filed Online                                                             NaN
# Incident Code                                                           7041
# Incident Category                                          Recovered Vehicle
# Incident Subcategory                                       Recovered Vehicle
# Incident Description                                Vehicle, Recovered, Auto
# Resolution                                                    Open or Active
# Intersection                                                             NaN
# CNN                                                                      NaN
# Police District                                                    Out of SF
# Analysis Neighborhood                                                    NaN
# Supervisor District                                                      NaN
# Latitude                                                                 NaN
# Longitude                                                                NaN
# point                                                                    NaN
# SF Find Neighborhoods                                                    NaN
# Current Police Districts                                                 NaN
# Current Supervisor Districts                                             NaN
# Analysis Neighborhoods                                                   NaN
# HSOC Zones as of 2018-06-05                                              NaN
# OWED Public Spaces                                                       NaN
# Central Market/Tenderloin Boundary Polygon - Up...                       NaN
# Parks Alliance CPSI (27+TL sites)                                        NaN
# ESNCAG - Boundary File                                                   NaN
# Areas of Vulnerability, 2016                                             NaN
#
#                                                                                     1  \
# Incident Datetime                                              2020/08/15 09:40:00 AM
# Incident Date                                                              2020/08/15
# Incident Time                                                                   09:40
# Incident Year                                                                    2020
# Incident Day of Week                                                         Saturday
# Report Datetime                                                2020/08/15 06:21:00 PM
# Row ID                                                                    95322706244
# Incident ID                                                                    953227
# Incident Number                                                             206121692
# CAD Number                                                                        NaN
# Report Type Code                                                                   II
# Report Type Description                                              Coplogic Initial
# Filed Online                                                                     True
# Incident Code                                                                    6244
# Incident Category                                                       Larceny Theft
# Incident Subcategory                                           Larceny - From Vehicle
# Incident Description                                Theft, From Locked Vehicle, >$950
# Resolution                                                             Open or Active
# Intersection                                                                      NaN
# CNN                                                                               NaN
# Police District                                                                  Park
# Analysis Neighborhood                                                             NaN
# Supervisor District                                                               NaN
# Latitude                                                                          NaN
# Longitude                                                                         NaN
# point                                                                             NaN
# SF Find Neighborhoods                                                             NaN
# Current Police Districts                                                          NaN
# Current Supervisor Districts                                                      NaN
# Analysis Neighborhoods                                                            NaN
# HSOC Zones as of 2018-06-05                                                       NaN
# OWED Public Spaces                                                                NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                NaN
# Parks Alliance CPSI (27+TL sites)                                                 NaN
# ESNCAG - Boundary File                                                            NaN
# Areas of Vulnerability, 2016                                                      NaN
#
#                                                                          2  \
# Incident Datetime                                   2018/02/24 10:00:00 PM
# Incident Date                                                   2018/02/24
# Incident Time                                                        22:00
# Incident Year                                                         2018
# Incident Day of Week                                              Saturday
# Report Datetime                                     2018/03/02 10:13:00 AM
# Row ID                                                         64174871000
# Incident ID                                                         641748
# Incident Number                                                  186051531
# CAD Number                                                             NaN
# Report Type Code                                                        II
# Report Type Description                                   Coplogic Initial
# Filed Online                                                          True
# Incident Code                                                        71000
# Incident Category                                            Lost Property
# Incident Subcategory                                         Lost Property
# Incident Description                                         Lost Property
# Resolution                                                  Open or Active
# Intersection                                                           NaN
# CNN                                                                    NaN
# Police District                                                       Park
# Analysis Neighborhood                                                  NaN
# Supervisor District                                                    NaN
# Latitude                                                               NaN
# Longitude                                                              NaN
# point                                                                  NaN
# SF Find Neighborhoods                                                  NaN
# Current Police Districts                                               NaN
# Current Supervisor Districts                                           NaN
# Analysis Neighborhoods                                                 NaN
# HSOC Zones as of 2018-06-05                                            NaN
# OWED Public Spaces                                                     NaN
# Central Market/Tenderloin Boundary Polygon - Up...                     NaN
# Parks Alliance CPSI (27+TL sites)                                      NaN
# ESNCAG - Boundary File                                                 NaN
# Areas of Vulnerability, 2016                                           NaN
#
#                                                                                                    3  \
# Incident Datetime                                                             2020/08/16 03:13:00 AM
# Incident Date                                                                             2020/08/16
# Incident Time                                                                                  03:13
# Incident Year                                                                                   2020
# Incident Day of Week                                                                          Sunday
# Report Datetime                                                               2020/08/16 03:14:00 AM
# Row ID                                                                                   95319604083
# Incident ID                                                                                   953196
# Incident Number                                                                            200491669
# CAD Number                                                                                2.0229e+08
# Report Type Code                                                                                  II
# Report Type Description                                                                      Initial
# Filed Online                                                                                     NaN
# Incident Code                                                                                   4083
# Incident Category                                                                            Assault
# Incident Subcategory                                                              Aggravated Assault
# Incident Description                                Firearm, Discharging in Grossly Negligent Manner
# Resolution                                                                            Open or Active
# Intersection                                                                   23RD ST \ ARKANSAS ST
# CNN                                                                                       2.3642e+07
# Police District                                                                              Bayview
# Analysis Neighborhood                                                                   Potrero Hill
# Supervisor District                                                                               10
# Latitude                                                                                     37.7548
# Longitude                                                                                   -122.398
# point                                                       (37.75482657770952, -122.39772873392515)
# SF Find Neighborhoods                                                                             54
# Current Police Districts                                                                           2
# Current Supervisor Districts                                                                       9
# Analysis Neighborhoods                                                                            26
# HSOC Zones as of 2018-06-05                                                                      NaN
# OWED Public Spaces                                                                               NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                               NaN
# Parks Alliance CPSI (27+TL sites)                                                                NaN
# ESNCAG - Boundary File                                                                           NaN
# Areas of Vulnerability, 2016                                                                       2
#
#                                                                                            4  \
# Incident Datetime                                                     2020/08/16 03:38:00 AM
# Incident Date                                                                     2020/08/16
# Incident Time                                                                          03:38
# Incident Year                                                                           2020
# Incident Day of Week                                                                  Sunday
# Report Datetime                                                       2020/08/16 04:56:00 AM
# Row ID                                                                           95326228100
# Incident ID                                                                           953262
# Incident Number                                                                    200491738
# CAD Number                                                                        2.0229e+08
# Report Type Code                                                                          II
# Report Type Description                                                              Initial
# Filed Online                                                                             NaN
# Incident Code                                                                          28100
# Incident Category                                                         Malicious Mischief
# Incident Subcategory                                                               Vandalism
# Incident Description                                    Malicious Mischief, Breaking Windows
# Resolution                                                                    Open or Active
# Intersection                                                           VALENCIA ST \ 15TH ST
# CNN                                                                               2.4377e+07
# Police District                                                                      Mission
# Analysis Neighborhood                                                                Mission
# Supervisor District                                                                        9
# Latitude                                                                             37.7665
# Longitude                                                                           -122.422
# point                                               (37.76653957529556, -122.42204381448558)
# SF Find Neighborhoods                                                                     53
# Current Police Districts                                                                   3
# Current Supervisor Districts                                                               2
# Analysis Neighborhoods                                                                    20
# HSOC Zones as of 2018-06-05                                                                3
# OWED Public Spaces                                                                       NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                       NaN
# Parks Alliance CPSI (27+TL sites)                                                        NaN
# ESNCAG - Boundary File                                                                   NaN
# Areas of Vulnerability, 2016                                                               2
#
#                                                                                            5  \
# Incident Datetime                                                     2020/08/16 01:40:00 PM
# Incident Date                                                                     2020/08/16
# Incident Time                                                                          13:40
# Incident Year                                                                           2020
# Incident Day of Week                                                                  Sunday
# Report Datetime                                                       2020/08/16 01:56:00 PM
# Row ID                                                                           95336264020
# Incident ID                                                                           953362
# Incident Number                                                                    200492463
# CAD Number                                                                       2.02292e+08
# Report Type Code                                                                          II
# Report Type Description                                                              Initial
# Filed Online                                                                             NaN
# Incident Code                                                                          64020
# Incident Category                                                               Non-Criminal
# Incident Subcategory                                                                   Other
# Incident Description                                                 Mental Health Detention
# Resolution                                                                    Open or Active
# Intersection                                                              04TH ST \ MINNA ST
# CNN                                                                               2.4631e+07
# Police District                                                                     Southern
# Analysis Neighborhood                                         Financial District/South Beach
# Supervisor District                                                                        6
# Latitude                                                                              37.784
# Longitude                                                                           -122.404
# point                                               (37.78404443715923, -122.40371175457705)
# SF Find Neighborhoods                                                                     32
# Current Police Districts                                                                   1
# Current Supervisor Districts                                                              10
# Analysis Neighborhoods                                                                     8
# HSOC Zones as of 2018-06-05                                                              NaN
# OWED Public Spaces                                                                       NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                       NaN
# Parks Alliance CPSI (27+TL sites)                                                        NaN
# ESNCAG - Boundary File                                                                   NaN
# Areas of Vulnerability, 2016                                                               1
#
#                                                                                                     6  \
# Incident Datetime                                                              2020/08/16 04:18:00 PM
# Incident Date                                                                              2020/08/16
# Incident Time                                                                                   16:18
# Incident Year                                                                                    2020
# Incident Day of Week                                                                           Sunday
# Report Datetime                                                                2020/08/16 04:18:00 PM
# Row ID                                                                                    95335012010
# Incident ID                                                                                    953350
# Incident Number                                                                             200492792
# CAD Number                                                                                2.02292e+08
# Report Type Code                                                                                   II
# Report Type Description                                                                       Initial
# Filed Online                                                                                      NaN
# Incident Code                                                                                   12010
# Incident Category                                                                     Weapons Offense
# Incident Subcategory                                                                  Weapons Offense
# Incident Description                                Weapon, Carrying Concealed with Felony or Narc...
# Resolution                                                                       Cite or Arrest Adult
# Intersection                                                                     ORTEGA ST \ 48TH AVE
# CNN                                                                                        2.7925e+07
# Police District                                                                               Taraval
# Analysis Neighborhood                                                                 Sunset/Parkside
# Supervisor District                                                                                 4
# Latitude                                                                                       37.751
# Longitude                                                                                    -122.507
# point                                                       (37.751003283475306, -122.50741622958954)
# SF Find Neighborhoods                                                                              39
# Current Police Districts                                                                           10
# Current Supervisor Districts                                                                        7
# Analysis Neighborhoods                                                                             35
# HSOC Zones as of 2018-06-05                                                                       NaN
# OWED Public Spaces                                                                                NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                                NaN
# Parks Alliance CPSI (27+TL sites)                                                                 NaN
# ESNCAG - Boundary File                                                                            NaN
# Areas of Vulnerability, 2016                                                                        1
#
#                                                                                            7  \
# Incident Datetime                                                     2020/08/12 10:00:00 PM
# Incident Date                                                                     2020/08/12
# Incident Time                                                                          22:00
# Incident Year                                                                           2020
# Incident Day of Week                                                               Wednesday
# Report Datetime                                                       2020/08/15 08:30:00 AM
# Row ID                                                                           95300674000
# Incident ID                                                                           953006
# Incident Number                                                                    200489880
# CAD Number                                                                       2.02281e+08
# Report Type Code                                                                          II
# Report Type Description                                                              Initial
# Filed Online                                                                             NaN
# Incident Code                                                                          74000
# Incident Category                                                             Missing Person
# Incident Subcategory                                                           Missing Adult
# Incident Description                                                           Missing Adult
# Resolution                                                                    Open or Active
# Intersection                                                           FILLMORE ST \ TURK ST
# CNN                                                                               2.5973e+07
# Police District                                                                     Northern
# Analysis Neighborhood                                                       Western Addition
# Supervisor District                                                                        5
# Latitude                                                                             37.7805
# Longitude                                                                           -122.432
# point                                               (37.78049625961115, -122.43214039079034)
# SF Find Neighborhoods                                                                     97
# Current Police Districts                                                                   4
# Current Supervisor Districts                                                              11
# Analysis Neighborhoods                                                                    39
# HSOC Zones as of 2018-06-05                                                              NaN
# OWED Public Spaces                                                                       NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                       NaN
# Parks Alliance CPSI (27+TL sites)                                                        NaN
# ESNCAG - Boundary File                                                                   NaN
# Areas of Vulnerability, 2016                                                               2
#
#                                                                                             8  \
# Incident Datetime                                                      2020/08/14 02:00:00 PM
# Incident Date                                                                      2020/08/14
# Incident Time                                                                           14:00
# Incident Year                                                                            2020
# Incident Day of Week                                                                   Friday
# Report Datetime                                                        2020/08/15 12:23:00 AM
# Row ID                                                                            95321406244
# Incident ID                                                                            953214
# Incident Number                                                                     206121551
# CAD Number                                                                                NaN
# Report Type Code                                                                           II
# Report Type Description                                                      Coplogic Initial
# Filed Online                                                                             True
# Incident Code                                                                            6244
# Incident Category                                                               Larceny Theft
# Incident Subcategory                                                   Larceny - From Vehicle
# Incident Description                                        Theft, From Locked Vehicle, >$950
# Resolution                                                                     Open or Active
# Intersection                                                           HEMLOCK ST \ LAGUNA ST
# CNN                                                                                2.6523e+07
# Police District                                                                      Northern
# Analysis Neighborhood                                                               Japantown
# Supervisor District                                                                         5
# Latitude                                                                              37.7862
# Longitude                                                                            -122.428
# point                                               (37.786246576578144, -122.42824149689217)
# SF Find Neighborhoods                                                                     101
# Current Police Districts                                                                    4
# Current Supervisor Districts                                                               11
# Analysis Neighborhoods                                                                     15
# HSOC Zones as of 2018-06-05                                                               NaN
# OWED Public Spaces                                                                        NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                        NaN
# Parks Alliance CPSI (27+TL sites)                                                         NaN
# ESNCAG - Boundary File                                                                    NaN
# Areas of Vulnerability, 2016                                                                2
#
#                                                                                             9
# Incident Datetime                                                      2020/08/16 11:13:00 AM
# Incident Date                                                                      2020/08/16
# Incident Time                                                                           11:13
# Incident Year                                                                            2020
# Incident Day of Week                                                                   Sunday
# Report Datetime                                                        2020/08/16 11:13:00 AM
# Row ID                                                                            95329661030
# Incident ID                                                                            953296
# Incident Number                                                                     200492350
# CAD Number                                                                        2.02291e+08
# Report Type Code                                                                           II
# Report Type Description                                                               Initial
# Filed Online                                                                              NaN
# Incident Code                                                                           61030
# Incident Category                                                                       Other
# Incident Subcategory                                                                    Other
# Incident Description                                              Death Report, Cause Unknown
# Resolution                                                                     Open or Active
# Intersection                                                          HYDE ST \ CALIFORNIA ST
# CNN                                                                                2.5252e+07
# Police District                                                                       Central
# Analysis Neighborhood                                                                Nob Hill
# Supervisor District                                                                         3
# Latitude                                                                               37.791
# Longitude                                                                            -122.417
# point                                               (37.790973190511274, -122.41739133606869)
# SF Find Neighborhoods                                                                      16
# Current Police Districts                                                                    6
# Current Supervisor Districts                                                                3
# Analysis Neighborhoods                                                                     21
# HSOC Zones as of 2018-06-05                                                               NaN
# OWED Public Spaces                                                                        NaN
# Central Market/Tenderloin Boundary Polygon - Up...                                        NaN
# Parks Alliance CPSI (27+TL sites)                                                         NaN
# ESNCAG - Boundary File                                                                    NaN
# Areas of Vulnerability, 2016                                                                1

# %% [markdown]
# To get a better idea of what the data looks like, let's do a simple histogram of the categories and crime descriptions.  Here is the category histogram:

# %%
df_sfpd['Incident Category'].unique()
# Out:
# array(['Recovered Vehicle', 'Larceny Theft', 'Lost Property', 'Assault',
#        'Malicious Mischief', 'Non-Criminal', 'Weapons Offense',
#        'Missing Person', 'Other', 'Burglary',
#        'Offences Against The Family And Children',
#        'Miscellaneous Investigation', 'Other Miscellaneous',
#        'Disorderly Conduct', 'Suspicious Occ', 'Other Offenses',
#        'Robbery', 'Motor Vehicle Theft', 'Family Offense', 'Arson',
#        'Case Closure', 'Suicide', 'Fraud', 'Traffic Violation Arrest',
#        'Stolen Property', 'Drug Offense', 'Vehicle Misplaced',
#        'Fire Report', 'Warrant', 'Forgery And Counterfeiting',
#        'Courtesy Report', 'Sex Offense', 'Traffic Collision', 'Vandalism',
#        'Weapons Carrying Etc', 'Embezzlement', nan, 'Vehicle Impounded',
#        'Rape', 'Human Trafficking (A), Commercial Sex Acts',
#        'Drug Violation', 'Motor Vehicle Theft?', 'Homicide', 'Gambling',
#        'Prostitution', 'Suspicious', 'Civil Sidewalks', 'Liquor Laws',
#        'Weapons Offence', 'Human Trafficking, Commercial Sex Acts',
#        'Human Trafficking (B), Involuntary Servitude'], dtype=object)

# %%
from collections import Counter
counter = Counter(df_sfpd['Incident Category'])
counter.most_common(10)
# Out:
# [('Larceny Theft', 120196),
#  ('Other Miscellaneous', 28791),
#  ('Malicious Mischief', 24307),
#  ('Non-Criminal', 23823),
#  ('Assault', 22955),
#  ('Burglary', 19583),
#  ('Motor Vehicle Theft', 15858),
#  ('Warrant', 13417),
#  ('Lost Property', 13081),
#  ('Recovered Vehicle', 12544)]

# %%
from collections import Counter
counter = Counter(df_sfpd['Incident Description'])
counter.most_common(10)
# Out:
# [('Theft, From Locked Vehicle, >$950', 50109),
#  ('Lost Property', 13081),
#  ('Theft, Other Property, $50-$200', 12001),
#  ('Malicious Mischief, Vandalism to Property', 11989),
#  ('Battery', 11358),
#  ('Theft, Other Property, >$950', 9569),
#  ('Mental Health Detention', 9502),
#  ('Vehicle, Recovered, Auto', 9312),
#  ('Vehicle, Stolen, Auto', 9022),
#  ('Theft, From Unlocked Vehicle, >$950', 7020)]

# %% [markdown]
# ## Word clouds
#
# A more interesting way to visualize differences in term frequency is using a so-called word cloud.  For example, here is a word cloud showing the categories from 2003 to the present.
#
# <img src="figures/SFPD-wordcloud.png" width="400">
#
# Python has a nice library you can use:
#
# ```bash
# $ pip install wordcloud
# ```
#
# **Exercise**: In a file called `catcloud.py`, once again get the categories and then create a word cloud object and display it:
#
# ```python
# from wordcloud import WordCloud
# import matplotlib.pyplot as plt
# from collections import Counter
# import pandas as pd
# import sys
#
# df_sfpd = pd.read_csv(sys.argv[1])
#
# ... delete Incident Categories with nan ...
# categories = ... create Counter object on column 'Incident Category' ...
#
# wordcloud = WordCloud(width=1800,
#                       height=1400,
#                       max_words=10000,
#                       random_state=1,
#                       relative_scaling=0.25)
#
# wordcloud.fit_words(categories)
#
# plt.imshow(wordcloud)
# plt.axis("off")
# plt.show()
# ```

# %% [markdown]
# ### Which neighborhood is the "worst"?
#
# **Exercise**: Now, pullout the neighborthood and do a word cloud on that in `hoodcloud.py` (it's ok to cut/paste):
#
# <img src="figures/SFPD-hood-wordcloud.png" width="400">

# %% [markdown]
# ### Crimes per neighborhood
#
#
# **Exercise**: Filter the data using pandas from a particular precinct or neighborhood, such as Mission and South of Market.  Modify `catcloud.py` to use a pandas query to filter for those records.  Pass the hood as an argument (`sys.argv[2]`):
#
# ```bash
# $ python catcloud.py /tmp/SFPD.csv Mission
# ```
#
# Run the `catcloud.py` script to get an idea of the types of crimes per those two neighborhoods. Here are the mission and SOMA districts crime category clouds:
#
# <table>
#     <tr>
#         <td><b>Mission</b></td><td>SOMA</td>
#     </tr>
#     <tr>
#         <td><img src="figures/SFPD-mission-wordcloud.png" width="300"></td><td><img src="figures/SFPD-soma-wordcloud.png" width="300"></td>
#     </tr>
#  </table>

# %% [markdown]
# ### Which neighborhood has most car break-ins?
#
# **Exercise**: Modify `hoodcloud.py` to filter for `Motor Vehicle Theft`. Pass the hood as an argument (`sys.argv[2]`):
#
# ```bash
# $ python hoodcloud.py /tmp/SFPD.csv 'Motor Vehicle Theft'
# ```
#
# <img src="figures/SFPD-car-theft-hood-wordcloud.png" width="300">
#
# Hmm..ok, so parking in the Mission is ok, but SOMA, BayView/Hunters point are bad news.
#
# If you get stuck in any of these exercises, you can look at the [code associated with this notes](https://github.com/parrt/msds692/tree/master/notes/code/sfpd).
